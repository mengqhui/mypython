# %%
from random import randint
l=[randint(800,999) for i in range(7000)]

# %%
l[3]
# Out:
# 858

# %%
l
# Out:
# [823,
#  848,
#  815,
#  858,
#  916,
#  847,
#  974,
#  819,
#  869,
#  893,
#  986,
#  804,
#  869,
#  902,
#  983,
#  868,
#  991,
#  845,
#  861,
#  839,
#  963,
#  998,
#  886,
#  998,
#  985,
#  997,
#  860,
#  886,
#  993,
#  937,
#  924,
#  918,
#  870,
#  918,
#  825,
#  998,
#  889,
#  983,
#  974,
#  972,
#  996,
#  826,
#  933,
#  990,
#  868,
#  892,
#  898,
#  929,
#  906,
#  860,
#  989,
#  925,
#  821,
#  823,
#  937,
#  889,
#  971,
#  830,
#  958,
#  832,
#  870,
#  929,
#  978,
#  996,
#  993,
#  861,
#  827,
#  985,
#  991,
#  888,
#  939,
#  826,
#  949,
#  844,
#  925,
#  990,
#  814,
#  889,
#  944,
#  898,
#  923,
#  902,
#  859,
#  883,
#  883,
#  803,
#  882,
#  844,
#  996,
#  932,
#  820,
#  829,
#  938,
#  848,
#  809,
#  829,
#  965,
#  946,
#  894,
#  814,
#  894,
#  914,
#  871,
#  876,
#  881,
#  829,
#  819,
#  943,
#  808,
#  979,
#  989,
#  969,
#  973,
#  961,
#  954,
#  970,
#  973,
#  944,
#  990,
#  819,
#  950,
#  932,
#  932,
#  950,
#  915,
# ...

# %%
fo = open(u"foo.txt","wb")
for num in l:
    fo.write(str(num)+'\n')
